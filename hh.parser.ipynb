# %% [markdown]
# # Парсим данные hh.ru
#
# ### Создаем файл json, куда записываем интересующую информацию

# %%
import requests
from bs4 import BeautifulSoup
import fake_useragent
import time
import datetime
import json

def get_links(text):
    ua = fake_useragent.UserAgent()
    page = 0
    url = f"https://krasnodar.hh.ru/search/vacancy?text={text}&from=suggest_post&items_on_page=20&search_field=name&page={page}" 
    print("Первая страница поиска:", url)
    data = requests.get(url, headers={"user-agent":ua.random})
    if data.status_code != 200:
        return
    soup = BeautifulSoup(data.content, "lxml")
    
    # Считает сколько страниц результатов
    try:
        page_count = int(soup.find("div", attrs={"class":"pager"}).find_all("span",recursive=False)[-1].find("a").find("span").text)   
        print("Число страниц поиска:", page_count) # по 20 результатов на каждой, иначе парсить придется по-другому    
    except:
        return
    
    # С каждой страницы результатов собирает и выводит ссылки 
    url_count = 0
    for page in range(page_count):
        try:
            data = requests.get(url, headers={"user-agent": ua.random})
            if data.status_code !=200:
                continue
            soup = BeautifulSoup(data.content, "lxml")
            for a in soup.find_all("a", attrs={"class":"serp-item__title"}):
                url_count+=1
                yield f'{a.attrs["href"]}'
        except Exception as e:
            print(f"{e}")
        time.sleep(1)
    print("Количество полученных адресов вакансий:", url_count)     
        
        
def get_vacancy(link):
    ua = fake_useragent.UserAgent()
    data = requests.get(
        url=link,
        headers={"user-agent":ua.random}
    )
    if data.status_code !=200:
        pass
    soup = BeautifulSoup(data.content,"lxml")
    try:
        name = soup.find(attrs={"class":"serp-item__title"}).text
    except:
        name = ""
    try:
        salary = soup.find("span",attrs={"data-qa":"vacancy-serp__vacancy-compensation"}).text.replace("\u202f"," ")
    except:
        salary = ""
    try:
        tags = [tag.text for tag in soup.find(attrs={"class":"bloko-tag-list"}).find_all("span",attrs={"class":"bloko-tag__section_text"})]
    except:                                                                              
        tags = []
    vacancy = {
        "name":name,
        "salary":salary,
        "tags":tags, 
        "url":link
    }
    return vacancy

if __name__ == "__main__": 
    today = datetime.datetime.today()
    # В имени не должно быть "/" и других запрещенных символов
    text = 'Data Scientist' # Это то, что мы вбиваем в поисковую строку hh.ru
    count = 0
    data = []
    for a in get_links(text):
        data.append(get_vacancy(a))
        time.sleep(1)
        with open(f"{text}_{today:%Y.%m.%d_%H.%M.%S}.json","w", encoding="utf-8") as f:
            
            # Добывляем отступ и отключаем проверку,
            # Чтобы русские буквы не заменялись английскими
            json.dump(data, f, indent=4, ensure_ascii=False)
            count += 1
            print(f"обработано запросов", count)
            
            if count == 10000: # вводим количество запросов. Для теста достаточно 3.
                break
# Out:
# Первая страница поиска: https://krasnodar.hh.ru/search/vacancy?text=Data Scientist&from=suggest_post&items_on_page=20&search_field=name&page=0
# Число страниц поиска: 20
# обработано запросов 1
# обработано запросов 2
# обработано запросов 3
# обработано запросов 4
# обработано запросов 5
# обработано запросов 6
# обработано запросов 7
# обработано запросов 8
# обработано запросов 9
# обработано запросов 10
# обработано запросов 11
# обработано запросов 12
# обработано запросов 13
# обработано запросов 14
# обработано запросов 15
# обработано запросов 16
# обработано запросов 17
# обработано запросов 18
# обработано запросов 19
# обработано запросов 20
# обработано запросов 21
# обработано запросов 22
# обработано запросов 23
# обработано запросов 24
# обработано запросов 25
# обработано запросов 26
# обработано запросов 27
# обработано запросов 28
# обработано запросов 29
# обработано запросов 30
# обработано запросов 31
# обработано запросов 32
# обработано запросов 33
# обработано запросов 34
# обработано запросов 35
# обработано запросов 36
# обработано запросов 37
# обработано запросов 38
# обработано запросов 39
# обработано запросов 40
# обработано запросов 41
# обработано запросов 42
# обработано запросов 43
# обработано запросов 44
# обработано запросов 45
# обработано запросов 46
# обработано запросов 47
# обработано запросов 48
# обработано запросов 49
# обработано запросов 50
# обработано запросов 51
# обработано запросов 52
# обработано запросов 53
# обработано запросов 54
# обработано запросов 55
# обработано запросов 56
# обработано запросов 57
# обработано запросов 58
# обработано запросов 59
# обработано запросов 60
# обработано запросов 61
# обработано запросов 62
# обработано запросов 63
# обработано запросов 64
# обработано запросов 65
# обработано запросов 66
# обработано запросов 67
# обработано запросов 68
# обработано запросов 69
# обработано запросов 70
# обработано запросов 71
# обработано запросов 72
# обработано запросов 73
# обработано запросов 74
# обработано запросов 75
# обработано запросов 76
# обработано запросов 77
# обработано запросов 78
# обработано запросов 79
# обработано запросов 80
# обработано запросов 81
# обработано запросов 82
# обработано запросов 83
# обработано запросов 84
# обработано запросов 85
# обработано запросов 86
# обработано запросов 87
# обработано запросов 88
# обработано запросов 89
# обработано запросов 90
# обработано запросов 91
# обработано запросов 92
# обработано запросов 93
# обработано запросов 94
# обработано запросов 95
# обработано запросов 96
# обработано запросов 97
# обработано запросов 98
# обработано запросов 99
# обработано запросов 100
# обработано запросов 101
# обработано запросов 102
# обработано запросов 103
# обработано запросов 104
# обработано запросов 105
# обработано запросов 106
# обработано запросов 107
# обработано запросов 108
# обработано запросов 109
# обработано запросов 110
# обработано запросов 111
# обработано запросов 112
# обработано запросов 113
# обработано запросов 114
# обработано запросов 115
# обработано запросов 116
# обработано запросов 117
# обработано запросов 118
# обработано запросов 119
# обработано запросов 120
# обработано запросов 121
# обработано запросов 122
# обработано запросов 123
# обработано запросов 124
# обработано запросов 125
# обработано запросов 126
# обработано запросов 127
# обработано запросов 128
# обработано запросов 129
# обработано запросов 130
# обработано запросов 131
# обработано запросов 132
# обработано запросов 133
# обработано запросов 134
# обработано запросов 135
# обработано запросов 136
# обработано запросов 137
# обработано запросов 138
# обработано запросов 139
# обработано запросов 140
# обработано запросов 141
# обработано запросов 142
# обработано запросов 143
# обработано запросов 144
# обработано запросов 145
# обработано запросов 146
# обработано запросов 147
# обработано запросов 148
# обработано запросов 149
# обработано запросов 150
# обработано запросов 151
# обработано запросов 152
# обработано запросов 153
# обработано запросов 154
# обработано запросов 155
# обработано запросов 156
# обработано запросов 157
# обработано запросов 158
# обработано запросов 159
# обработано запросов 160
# обработано запросов 161
# обработано запросов 162
# обработано запросов 163
# обработано запросов 164
# обработано запросов 165
# обработано запросов 166
# обработано запросов 167
# обработано запросов 168
# обработано запросов 169
# обработано запросов 170
# обработано запросов 171
# обработано запросов 172
# обработано запросов 173
# обработано запросов 174
# обработано запросов 175
# обработано запросов 176
# обработано запросов 177
# обработано запросов 178
# обработано запросов 179
# обработано запросов 180
# обработано запросов 181
# обработано запросов 182
# обработано запросов 183
# обработано запросов 184
# обработано запросов 185
# обработано запросов 186
# обработано запросов 187
# обработано запросов 188
# обработано запросов 189
# обработано запросов 190
# обработано запросов 191
# обработано запросов 192
# обработано запросов 193
# обработано запросов 194
# обработано запросов 195
# обработано запросов 196
# обработано запросов 197
# обработано запросов 198
# обработано запросов 199
# обработано запросов 200
# обработано запросов 201
# обработано запросов 202
# обработано запросов 203
# обработано запросов 204
# обработано запросов 205
# обработано запросов 206
# обработано запросов 207
# обработано запросов 208
# обработано запросов 209
# обработано запросов 210
# обработано запросов 211
# обработано запросов 212
# обработано запросов 213
# обработано запросов 214
# обработано запросов 215
# обработано запросов 216
# обработано запросов 217
# обработано запросов 218
# обработано запросов 219
# обработано запросов 220
# обработано запросов 221
# обработано запросов 222
# обработано запросов 223
# обработано запросов 224
# обработано запросов 225
# обработано запросов 226
# обработано запросов 227
# обработано запросов 228
# обработано запросов 229
# обработано запросов 230
# обработано запросов 231
# обработано запросов 232
# обработано запросов 233
# обработано запросов 234
# обработано запросов 235
# обработано запросов 236
# обработано запросов 237
# обработано запросов 238
# обработано запросов 239
# обработано запросов 240
# обработано запросов 241
# обработано запросов 242
# обработано запросов 243
# обработано запросов 244
# обработано запросов 245
# обработано запросов 246
# обработано запросов 247
# обработано запросов 248
# обработано запросов 249
# обработано запросов 250
# обработано запросов 251
# обработано запросов 252
# обработано запросов 253
# обработано запросов 254
# обработано запросов 255
# обработано запросов 256
# обработано запросов 257
# обработано запросов 258
# обработано запросов 259
# обработано запросов 260
# обработано запросов 261
# обработано запросов 262
# обработано запросов 263
# обработано запросов 264
# обработано запросов 265
# обработано запросов 266
# обработано запросов 267
# обработано запросов 268
# обработано запросов 269
# обработано запросов 270
# обработано запросов 271
# обработано запросов 272
# обработано запросов 273
# обработано запросов 274
# обработано запросов 275
# обработано запросов 276
# обработано запросов 277
# обработано запросов 278
# обработано запросов 279
# обработано запросов 280
# обработано запросов 281
# обработано запросов 282
# обработано запросов 283
# обработано запросов 284
# обработано запросов 285
# обработано запросов 286
# обработано запросов 287
# обработано запросов 288
# обработано запросов 289
# обработано запросов 290
# обработано запросов 291
# обработано запросов 292
# обработано запросов 293
# обработано запросов 294
# обработано запросов 295
# обработано запросов 296
# обработано запросов 297
# обработано запросов 298
# обработано запросов 299
# обработано запросов 300
# обработано запросов 301
# обработано запросов 302
# обработано запросов 303
# обработано запросов 304
# обработано запросов 305
# обработано запросов 306
# обработано запросов 307
# обработано запросов 308
# обработано запросов 309
# обработано запросов 310
# обработано запросов 311
# обработано запросов 312
# обработано запросов 313
# обработано запросов 314
# обработано запросов 315
# обработано запросов 316
# обработано запросов 317
# обработано запросов 318
# обработано запросов 319
# обработано запросов 320
# обработано запросов 321
# обработано запросов 322
# обработано запросов 323
# обработано запросов 324
# обработано запросов 325
# обработано запросов 326
# обработано запросов 327
# обработано запросов 328
# обработано запросов 329
# обработано запросов 330
# обработано запросов 331
# обработано запросов 332
# обработано запросов 333
# обработано запросов 334
# обработано запросов 335
# обработано запросов 336
# обработано запросов 337
# обработано запросов 338
# обработано запросов 339
# обработано запросов 340
# обработано запросов 341
# обработано запросов 342
# обработано запросов 343
# обработано запросов 344
# обработано запросов 345
# обработано запросов 346
# обработано запросов 347
# обработано запросов 348
# обработано запросов 349
# обработано запросов 350
# обработано запросов 351
# обработано запросов 352
# обработано запросов 353
# обработано запросов 354
# обработано запросов 355
# обработано запросов 356
# обработано запросов 357
# обработано запросов 358
# обработано запросов 359
# обработано запросов 360
# обработано запросов 361
# обработано запросов 362
# обработано запросов 363
# обработано запросов 364
# обработано запросов 365
# обработано запросов 366
# обработано запросов 367
# обработано запросов 368
# обработано запросов 369
# обработано запросов 370
# обработано запросов 371
# обработано запросов 372
# обработано запросов 373
# обработано запросов 374
# обработано запросов 375
# обработано запросов 376
# обработано запросов 377
# обработано запросов 378
# обработано запросов 379
# обработано запросов 380
# обработано запросов 381
# обработано запросов 382
# обработано запросов 383
# обработано запросов 384
# обработано запросов 385
# обработано запросов 386
# обработано запросов 387
# обработано запросов 388
# обработано запросов 389
# обработано запросов 390
# обработано запросов 391
# обработано запросов 392
# обработано запросов 393
# обработано запросов 394
# обработано запросов 395
# обработано запросов 396
# обработано запросов 397
# обработано запросов 398
# обработано запросов 399
# обработано запросов 400
# Количество полученных адресов вакансий: 400

# %% [markdown]
# # Работа с полученным json

# %%
# Пример нормализации данных json
# https://habr.com/ru/companies/otus/articles/731844

import pandas as pd
import json

df = pd.read_json('Data Scientist_2023.08.12_11.52.16.json')
df['name'] = df['name'].str.lower()

# Чтобы развернуть столбец tags, который содержит список строк, применим метод explode
exploded_df = df.explode('tags',ignore_index = True)
exploded_df['tags'] = exploded_df['tags'].str.lower()

# Объединяю синонимы в навыках. Заменяю значения на самый популярный синоним
# ---------------------------------------------------------------------------
for tag in ["machine learning",
            "машинное обучение",
            "методы машинного обучения",
            ]:
    exploded_df.loc[exploded_df["tags"] == tag] = "ml"
    
for tag in ["data analysis",
            ]:
    exploded_df.loc[exploded_df["tags"] == tag] = "анализ данных"
    
for tag in ["статистический анализ",
            "mathematics",
            ]:
    exploded_df.loc[exploded_df["tags"] == tag] = "математическая статистика"    
# ---------------------------------------------------------------------------

# Считаю частоту навыков
tags_freq = exploded_df['tags'].value_counts()

# Считаю частоту использования имени вакансии
name_freq = df['name'].value_counts()

# Считаю среднее число навыков на вакансию
sum_tags = exploded_df.shape[0] # кол. строк = числу навыков
sum_names = df.shape[0] # кол. строк = числу вакансий

print("Среднее число навыков на вакансию: ", round((sum_tags / sum_names), 1))
print ('************')
print (tags_freq) # выводим частоту использования тегов
print ('************')
print (name_freq)# выводим частоту использования названий вакансий
# Out:
# Среднее число навыков на вакансию:  6.3
# ************
# ml                                      487
# python                                  287
# sql                                     147
# pytorch                                 140
# data science                            100
# математическая статистика                87
# tensorflow                               73
# pandas                                   67
# linux                                    60
# английский — b2 — средне-продвинутый     53
# hadoop                                   47
# numpy                                    47
# scikit-learn                             47
# nlp                                      47
# анализ данных                            47
# big data                                 40
# airflow                                  40
# английский язык                          40
# английский — c1 — продвинутый            40
# computer vision                          33
# presto                                   27
# hive                                     27
# a/b-experiments                          27
# recommender systems                      27
# search ranking                           27
# neural nets                              27
# scipy                                    27
# руководство коллективом                  20
# 3d mesh                                  20
# object detection                         20
# c++                                      20
# pydata                                   20
# git                                      20
# английский — a1 — начальный              20
# docker                                   20
# spark                                    20
# прогнозирование                          20
# ms sql                                   20
# математическое моделирование             20
# аналитическое мышление                   20
# базы данных                              20
# ооп                                      20
# lightgbm                                 20
# face detection                           13
# face analyze                             13
# java                                      7
# Name: tags, dtype: int64
# ************
# data scientist                                                 80
# middle data scientist (маркетплейс)                            40
# remote ai developer                                            40
# data scientist middle+/senior                                  33
# data scientist (кредитный скоринг)                             20
# data scientist – computer vision                               20
#                                                                20
# специалист по углубленной аналитике данных (data scientist)    20
# senior ml engineer, large language & behavior models (llm)     20
# data-analyst (кипр)                                            20
# senior ml engineer в команду «матчинг»                         20
# data scientist (c++)                                           20
# с++ programmer (vehicle simulation), remote                    20
# старший ml- разработчик                                        20
# analyst/data science                                            7
# Name: name, dtype: int64
